# %%
pip install -r '/Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy>=1.21.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 2)) (2.3.5)
# Requirement already satisfied: pandas>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 3)) (2.3.3)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 4)) (1.16.3)
# Requirement already satisfied: matplotlib>=3.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 7)) (3.10.0)
# Requirement already satisfied: seaborn>=0.11.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 8)) (0.13.2)
# Requirement already satisfied: plotly>=5.0.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 9)) (6.5.2)
# Requirement already satisfied: scikit-learn>=0.24.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 12)) (1.8.0)
# Requirement already satisfied: statsmodels>=0.12.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 13)) (0.14.6)
# Requirement already satisfied: notebook>=6.0.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (7.5.3)
# Requirement already satisfied: jupyterlab>=3.0.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (4.5.4)
# Requirement already satisfied: ipykernel>=6.0.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (7.2.0)
# Requirement already satisfied: tqdm>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 21)) (4.67.3)
# Requirement already satisfied: jsonschema>=3.2.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 22)) (4.26.0)
# Requirement already satisfied: requests>=2.25.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 23)) (2.32.5)
# Requirement already satisfied: ollama>=0.0.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 25)) (0.6.1)
# Requirement already satisfied: missingno>=0.4.2 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 26)) (0.5.2)
# Requirement already satisfied: openpyxl>=3.0.7 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from -r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 27)) (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.3.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.3.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.3.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 3)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.4.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.4.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.4.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 7)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.4.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 7)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.4.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 7)) (26.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.4.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 7)) (12.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.4.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 7)) (3.3.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from plotly>=5.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 9)) (2.16.0)
# Requirement already satisfied: joblib>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn>=0.24.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 12)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from scikit-learn>=0.24.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 12)) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from statsmodels>=0.12.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 13)) (1.0.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (6.5.4)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (3.1.6)
# Requirement already satisfied: jupyter-core in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (82.0.0)
# Requirement already satisfied: traitlets in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (5.14.3)
# Requirement already satisfied: anyio in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (4.12.1)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (8.8.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.13.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (9.10.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (7.2.2)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=3.2.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 22)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jsonschema>=3.2.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 22)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jsonschema>=3.2.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 22)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jsonschema>=3.2.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 22)) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.25.1->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 23)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.25.1->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 23)) (2.6.3)
# Requirement already satisfied: pydantic>=2.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ollama>=0.0.1->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 25)) (2.12.5)
# Requirement already satisfied: et-xmlfile in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from openpyxl>=3.0.7->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 27)) (2.0.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (25.1.0)
# Requirement already satisfied: decorator>=4.3.2 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (0.8.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (3.0.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-core->jupyterlab>=3.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 17)) (4.9.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.9->ollama>=0.0.1->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 25)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.9->ollama>=0.0.1->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 25)) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.9->ollama>=0.0.1->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 25)) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.9->ollama>=0.0.1->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 25)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 3)) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 20)) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /Users/I585032/Library/Python/3.13/lib/python/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.0.0->-r /Users/I585032/Desktop/AI Data Analyst M1/requirements 3.txt (line 16)) (1.4.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Bibliotheken importieren und Daten laden
#
# Erläuterung: Hier laden wir alle notwendigen Bibliotheken für die Analyse und Visualisierung sowie den Datensatz selbst.

# %%
# Import helpful packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from scipy import stats
import missingno as msno
# from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


# Matplotlib setting for Jupyter Notebook
# %matplotlib inline

# %%
# sns.set(color_codes=True)
plt.style.use('ggplot')
 
# Configuration
input = "/Users/I585032/Desktop/AI Data Analyst M1" #hier muss der Pfad zu meiner Datei stehen
INPUT_FILE = os.path.join(input, "hotel_bookings 2.csv")
PROFILE_FILE = os.path.join(input, "hotel_bookings 2.html")
CREATE_PROFILE = True
 
df_raw = pd.read_csv(INPUT_FILE, encoding='latin1')

# %% [markdown]
# ## 2. Übersicht und grundlegende Informationen
#
# Erläuterung: Diese Schritte geben einen ersten Überblick über den Datensatz, seine Struktur, Datentypen und grundlegende statistische Kennzahlen.

# %%
df = df_raw


# Erste und letzte Zeilen anzeigen
print("Erste 5 Zeilen des Datensatzes:")
display(df.head())
print("\nLetzte 5 Zeilen des Datensatzes:")
display(df.tail())

# Grundlegende Informationen
print("\nGrundlegende Informationen:")
display(df.info())

# Datentypen identifizieren
print("\nDatentypen pro Spalte:")
display(df.dtypes.value_counts())
print("\nListe aller Spalten mit ihren Datentypen:")
display(df.dtypes)

# Separate Listen für numerische und kategoriale Spalten erstellen
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()
categorical_columns = df.select_dtypes(exclude=['number']).columns.tolist()

print(f"\nNumerische Spalten ({len(numeric_columns)}): {numeric_columns}")
print(f"Kategoriale Spalten ({len(categorical_columns)}): {categorical_columns}")

# Größe des Datensatzes
print(f"\nDatensatzgröße: {df.shape[0]} Zeilen und {df.shape[1]} Spalten")
# Out:
# Erste 5 Zeilen des Datensatzes:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]
# Letzte 5 Zeilen des Datensatzes:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  adults  ...  deposit_type  agent company  \
# 119385                     5       2  ...    No Deposit  394.0     NaN
# 119386                     5       3  ...    No Deposit    9.0     NaN
# 119387                     5       2  ...    No Deposit    9.0     NaN
# 119388                     5       2  ...    No Deposit   89.0     NaN
# 119389                     7       2  ...    No Deposit    9.0     NaN
#
#        days_in_waiting_list customer_type     adr  \
# 119385                    0     Transient   96.14
# 119386                    0     Transient  225.43
# 119387                    0     Transient  157.71
# 119388                    0     Transient  104.40
# 119389                    0     Transient  151.20
#
#         required_car_parking_spaces  total_of_special_requests  \
# 119385                            0                          0
# 119386                            0                          2
# 119387                            0                          4
# 119388                            0                          0
# 119389                            0                          2
#
#         reservation_status reservation_status_date
# 119385           Check-Out              2017-09-06
# 119386           Check-Out              2017-09-07
# 119387           Check-Out              2017-09-07
# 119388           Check-Out              2017-09-07
# 119389           Check-Out              2017-09-07
#
# [5 rows x 32 columns]
# Grundlegende Informationen:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB
# None
# Datentypen pro Spalte:
# int64      16
# object     12
# float64     4
# Name: count, dtype: int64
# Liste aller Spalten mit ihren Datentypen:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# deposit_type                       object
# agent                             float64
# company                           float64
# days_in_waiting_list                int64
# customer_type                      object
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# reservation_status                 object
# reservation_status_date            object
# dtype: object
# Numerische Spalten (20): ['is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']
# Kategoriale Spalten (12): ['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status', 'reservation_status_date']
#
# Datensatzgröße: 119390 Zeilen und 32 Spalten

# %% [markdown]
# ## 3. Prüfung auf fehlende Werte
#
# Erläuterung: Hier identifizieren wir fehlende Werte im Datensatz und visualisieren deren Muster.

# %%
# Anzahl und Prozentsatz fehlender Werte pro Spalte
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100
missing_info = pd.DataFrame({
    'Fehlende Werte': missing_values,
    'Prozent (%)': missing_percentage
})
missing_info = missing_info[missing_info['Fehlende Werte'] > 0].sort_values('Prozent (%)', ascending=False)

print("Fehlende Werte pro Spalte:")
if len(missing_info) > 0:
    display(missing_info)
else:
    print("Keine fehlenden Werte gefunden")

# Visualisierung fehlender Werte mit verschiedenen Plots
if missing_values.sum() > 0:
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    msno.matrix(df)
    plt.title('Matrix fehlender Werte')
    
    plt.subplot(1, 2, 2)
    msno.heatmap(df)
    plt.title('Heatmap der fehlenden Werte')
    plt.tight_layout()
    plt.show()
    
    # Bar-Plot für fehlende Werte
    plt.figure(figsize=(12, 6))
    missing_info.sort_values('Fehlende Werte').plot(
        kind='barh', y='Prozent (%)', 
        color='crimson', 
        title='Prozentsatz fehlender Werte pro Spalte'
    )
    plt.tight_layout()
    plt.show()
    
    # Zusammenhang zwischen fehlenden Werten visualisieren
    plt.figure(figsize=(10, 8))
    msno.dendrogram(df)
    plt.title('Dendrogram der fehlenden Werte')
    plt.show()
# Out:
# Fehlende Werte pro Spalte:
#           Fehlende Werte  Prozent (%)
# company           112593    94.306893
# agent              16340    13.686238
# country              488     0.408744
# children               4     0.003350

# %% [markdown]
# ## 4. Univariate Analyse - Verteilungen einzelner Variablen
#
# Erläuterung: Diese Visualisierungen zeigen die Verteilungen jeder einzelnen Variable. Histogramme zeigen die Form der Verteilung, Boxplots identifizieren Ausreißer, und QQ-Plots prüfen auf Normalverteilung.

# %%
# Statistische Zusammenfassung für numerische Spalten
if len(numeric_columns) > 0:
    print("\nStatistische Zusammenfassung numerischer Spalten:")
    display(df[numeric_columns].describe().T)

# Häufigkeitsverteilungen für kategoriale Spalten
if len(categorical_columns) > 0:
    print("\nHäufigkeitsverteilungen kategorialer Spalten:")
    for col in categorical_columns:
        print(f"\n{col}:")
        display(df[col].value_counts().head(10))  # Top 10 häufigste Werte
        print(f"Anzahl eindeutiger Werte: {df[col].nunique()}")

# Histogramme und Dichteplots für numerische Variablen
if len(numeric_columns) > 0:
    rows = int(np.ceil(len(numeric_columns) / 3))
    plt.figure(figsize=(18, rows * 4))
    for i, column in enumerate(numeric_columns):
        plt.subplot(rows, 3, i+1)
        sns.histplot(df[column].dropna(), kde=True)
        plt.title(f'Verteilung: {column}')
    plt.tight_layout()
    plt.show()

# Box-Plots für numerische Variablen
if len(numeric_columns) > 0:
    rows = int(np.ceil(len(numeric_columns) / 3))
    plt.figure(figsize=(18, rows * 4))
    for i, column in enumerate(numeric_columns):
        plt.subplot(rows, 3, i+1)
        sns.boxplot(y=df[column].dropna())
        plt.title(f'Boxplot: {column}')
    plt.tight_layout()
    plt.show()

# Balkendiagramme für kategoriale Variablen
if len(categorical_columns) > 0:
    for col in categorical_columns:
        plt.figure(figsize=(12, 6))
        top_cats = df[col].value_counts().head(20)  # Top 20 Kategorien
        sns.barplot(x=top_cats.index, y=top_cats.values)
        plt.title(f'Top 20 Werte: {col}')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()
# Out:
# Statistische Zusammenfassung numerischer Spalten:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# previous_cancellations          119390.0     0.087118    0.844336     0.00
# previous_bookings_not_canceled  119390.0     0.137097    1.497437     0.00
# booking_changes                 119390.0     0.221124    0.652306     0.00
# agent                           103050.0    86.693382  110.774548     1.00
# company                           6797.0   189.266735  131.655015     6.00
# days_in_waiting_list            119390.0     2.321149   17.594721     0.00
# adr                             119390.0   101.831122   50.535790    -6.38
# required_car_parking_spaces     119390.0     0.062518    0.245291     0.00
# total_of_special_requests       119390.0     0.571363    0.792798     0.00
#
#                                     25%       50%     75%     max
# is_canceled                        0.00     0.000     1.0     1.0
# lead_time                         18.00    69.000   160.0   737.0
# arrival_date_year               2016.00  2016.000  2017.0  2017.0
# arrival_date_week_number          16.00    28.000    38.0    53.0
# arrival_date_day_of_month          8.00    16.000    23.0    31.0
# stays_in_weekend_nights            0.00     1.000     2.0    19.0
# stays_in_week_nights               1.00     2.000     3.0    50.0
# adults                             2.00     2.000     2.0    55.0
# children                           0.00     0.000     0.0    10.0
# babies                             0.00     0.000     0.0    10.0
# is_repeated_guest                  0.00     0.000     0.0     1.0
# previous_cancellations             0.00     0.000     0.0    26.0
# previous_bookings_not_canceled     0.00     0.000     0.0    72.0
# booking_changes                    0.00     0.000     0.0    21.0
# agent                              9.00    14.000   229.0   535.0
# company                           62.00   179.000   270.0   543.0
# days_in_waiting_list               0.00     0.000     0.0   391.0
# adr                               69.29    94.575   126.0  5400.0
# required_car_parking_spaces        0.00     0.000     0.0     8.0
# total_of_special_requests          0.00     0.000     1.0     5.0
# Häufigkeitsverteilungen kategorialer Spalten:
#
# hotel:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 2
#
# arrival_date_month:
# arrival_date_month
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 12
#
# meal:
# meal
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 5
#
# country:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# ITA     3766
# IRL     3375
# BEL     2342
# BRA     2224
# NLD     2104
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 177
#
# market_segment:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 8
#
# distribution_channel:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 5
#
# reserved_room_type:
# reserved_room_type
# A    85994
# D    19201
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 10
#
# assigned_room_type:
# assigned_room_type
# A    74053
# D    25322
# E     7806
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 12
#
# deposit_type:
# deposit_type
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 3
#
# customer_type:
# customer_type
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 4
#
# reservation_status:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 3
#
# reservation_status_date:
# reservation_status_date
# 2015-10-21    1461
# 2015-07-06     805
# 2016-11-25     790
# 2015-01-01     763
# 2016-01-18     625
# 2015-07-02     469
# 2016-12-07     450
# 2015-12-18     423
# 2016-02-09     412
# 2016-04-04     382
# Name: count, dtype: int64
# Anzahl eindeutiger Werte: 926

# %% [markdown]
# ## 5. Ausreißeranalyse
#
# Erläuterung: Hier identifizieren wir Ausreißer mit zwei verschiedenen Methoden: Z-Score und IQR-Methode.

# %%
z_scores = pd.DataFrame(index=df.index)  # Gleiche Zeilen wie df

for column in numeric_columns:
    # Daten der Spalte
    col_data = df[column]
    
    # a) Wenn keine NAs vorhanden sind, einfach den Z-Score berechnen
    if col_data.isnull().sum() == 0:
        z_scores[column] = np.abs(stats.zscore(col_data))
    
    # b) Wenn NAs vorhanden sind:
    else:
        # Nur die non-null-Werte extrahieren
        non_null_data = col_data.dropna()
        
        # Z-Score berechnen für nur diese Werte
        z = stats.zscore(non_null_data)
        
        # Als Series anlegen und den Index wie die non-null-Werte setzen
        z_series = pd.Series(z, index=non_null_data.index)
        
        # Anschließend in die entsprechende Spalte des z_scores-Datensatzes übernehmen
        # und für die NA-Positionen von df automatisch mit NaN auffüllen
        z_scores[column] = z_series

# Jetzt hast du ein DataFrame z_scores mit gleicher Zeilenlänge wie df, 
# in dem für jede numerische Spalte die Z-Scores stehen (NaN an den Stellen, an denen df[column] fehlte).

# Ausreißer identifizieren (|z| > 3)
print("Anzahl der Ausreißer pro numerischer Spalte (|z| > 3):")
display((z_scores > 3).sum())

# IQR-Methode bleibt unverändert
outliers_count = {}
for column in numeric_columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    outliers = ((df[column] < (Q1 - 1.5 * IQR)) | (df[column] > (Q3 + 1.5 * IQR))).sum()
    outliers_count[column] = outliers

print("\nAnzahl der Ausreißer pro Spalte (IQR-Methode):")
display(pd.Series(outliers_count))
# Out:
# Anzahl der Ausreißer pro numerischer Spalte (|z| > 3):
# is_canceled                          0
# lead_time                         1454
# arrival_date_year                    0
# arrival_date_week_number             0
# arrival_date_day_of_month            0
# stays_in_weekend_nights           2199
# stays_in_week_nights              1669
# adults                             481
# children                          3729
# babies                             917
# is_repeated_guest                 3810
# previous_cancellations             317
# previous_bookings_not_canceled     936
# booking_changes                   1570
# agent                              797
# company                              0
# days_in_waiting_list              1871
# adr                               1138
# required_car_parking_spaces       7416
# total_of_special_requests         2877
# dtype: int64
# Anzahl der Ausreißer pro Spalte (IQR-Methode):
# is_canceled                           0
# lead_time                          3005
# arrival_date_year                     0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights             265
# stays_in_week_nights               3354
# adults                            29710
# children                           8590
# babies                              917
# is_repeated_guest                  3810
# previous_cancellations             6484
# previous_bookings_not_canceled     3620
# booking_changes                   18076
# agent                                 0
# company                               0
# days_in_waiting_list               3698
# adr                                3793
# required_car_parking_spaces        7416
# total_of_special_requests          2877
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import matplotlib.patches as mpatches

# Bereich der x-Werte für die Normalverteilung
x = np.linspace(-4, 4, 1000)

# Wahrscheinlichkeitsdichtefunktion der Standardnormalverteilung
y = stats.norm.pdf(x, 0, 1)

# Figur und Achsen erstellen
fig, ax = plt.subplots(figsize=(10, 6))

# Normalverteilungskurve zeichnen
ax.plot(x, y, 'b-', linewidth=2, label='Standardnormalverteilung')

# Fläche für |z| > 3 füllen
ax.fill_between(x, y, where=(x <= -3) | (x >= 3), color='red', alpha=0.3)

# Vertikale Linien für z = -3 und z = 3
ax.axvline(x=3, color='r', linestyle='--', linewidth=1.5)
ax.axvline(x=-3, color='r', linestyle='--', linewidth=1.5)

# Beschriftungen
ax.set_title('Standardnormalverteilung mit Z-Score = 3', fontsize=15)
ax.set_xlabel('Z-Score (Anzahl der Standardabweichungen)', fontsize=12)
ax.set_ylabel('Wahrscheinlichkeitsdichte', fontsize=12)

# Anmerkungen hinzufügen
ax.annotate('Z = 3', xy=(3, stats.norm.pdf(3, 0, 1)), 
            xytext=(3.2, 0.1), 
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5))

ax.annotate('Z = -3', xy=(-3, stats.norm.pdf(-3, 0, 1)), 
            xytext=(-3.8, 0.1), 
            arrowprops=dict(facecolor='black', shrink=0.05, width=1.5))

# Prozentsätze berechnen
pct_beyond_3 = 100 * (1 - (stats.norm.cdf(3) - stats.norm.cdf(-3)))

# Statistischen Kontext hinzufügen
ax.text(0, 0.2, f"Bereich |Z| > 3 enthält nur {pct_beyond_3:.4f}% aller Werte\n"
                f"(ca. 1 von {int(1/(pct_beyond_3/100))} Werten)", 
        ha='center', va='center', bbox=dict(facecolor='white', alpha=0.8))

# Legende hinzufügen
normal_patch = mpatches.Patch(color='blue', alpha=0.3, label='68-95-99.7 Regel:')
z1_patch = mpatches.Patch(color='blue', alpha=0.3, label='|Z| < 1: 68% der Daten')
z2_patch = mpatches.Patch(color='blue', alpha=0.3, label='|Z| < 2: 95% der Daten')
z3_patch = mpatches.Patch(color='blue', alpha=0.3, label='|Z| < 3: 99.7% der Daten')
outlier_patch = mpatches.Patch(color='red', alpha=0.3, label='Ausreißerbereich: |Z| > 3')

plt.legend(handles=[normal_patch, z1_patch, z2_patch, z3_patch, outlier_patch], 
           loc='upper right', bbox_to_anchor=(1, 0.95))

# Grid hinzufügen
ax.grid(True, linestyle='--', alpha=0.7)

# Achsenbegrenzungen festlegen
ax.set_xlim(-4, 4)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Bivariate Analyse - Mit Berücksichtigung verschiedener Datentypen

# %%
# Korrelation zwischen numerischen Variablen (mit berücksichtigung fehlender Werte)
if len(numeric_columns) >= 2:
    # Korrelationsmatrix mit paarweisem Ausschluss fehlender Werte
    corr_matrix = df[numeric_columns].corr(method='pearson', min_periods=1)
    
    plt.figure(figsize=(14, 12))
    mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    sns.heatmap(corr_matrix, mask=mask, cmap=cmap, annot=True, fmt='.2f', 
                square=True, linewidths=.5, center=0)
    plt.title('Korrelationsmatrix numerischer Variablen')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    
    # Top 10 stärkste Korrelationen
    corr_pairs = corr_matrix.unstack()
    corr_pairs = corr_pairs[corr_pairs < 1.0]  # Selbstkorrelationen ausschließen
    high_corr = corr_pairs.abs().sort_values(ascending=False).head(10)
    print("Top 10 stärkste Korrelationen:")
    display(high_corr)

# Analyse kategorischer vs. numerischer Variablen
if len(categorical_columns) > 0 and len(numeric_columns) > 0:
    # Für jede Kombination aus kategorischer und numerischer Variable
    for cat_col in categorical_columns[:3]:  # Begrenzen auf die ersten 3 kategorialen Spalten
        unique_cats = df[cat_col].nunique()
        if unique_cats < 10:  # Nur für kategoriale Spalten mit wenigen eindeutigen Werten
            for num_col in numeric_columns[:5]:  # Begrenzen auf die ersten 5 numerischen Spalten
                plt.figure(figsize=(12, 6))
                sns.boxplot(x=cat_col, y=num_col, data=df)
                plt.title(f'Boxplot: {num_col} nach {cat_col}')
                plt.xticks(rotation=45, ha='right')
                plt.tight_layout()
                plt.show()

# Analyse zwischen kategorischen Variablen
if len(categorical_columns) >= 2:
    # Für ausgewählte Paare kategorialer Variablen
    for i, cat_col1 in enumerate(categorical_columns[:2]):  # Erste 2 kategoriale Spalten
        for cat_col2 in categorical_columns[i+1:i+2]:  # Die nächste kategoriale Spalte
            if df[cat_col1].nunique() < 10 and df[cat_col2].nunique() < 10:
                plt.figure(figsize=(12, 8))
                ct = pd.crosstab(df[cat_col1], df[cat_col2], normalize='index')
                sns.heatmap(ct, annot=True, fmt='.2f', cmap='viridis')
                plt.title(f'Kreuztabelle: {cat_col1} vs {cat_col2}')
                plt.tight_layout()
                plt.show()
# Out:
# Top 10 stärkste Korrelationen:
# arrival_date_week_number        arrival_date_year                 0.540561
# arrival_date_year               arrival_date_week_number          0.540561
# stays_in_weekend_nights         stays_in_week_nights              0.498969
# stays_in_week_nights            stays_in_weekend_nights           0.498969
# is_repeated_guest               previous_bookings_not_canceled    0.418056
# previous_bookings_not_canceled  is_repeated_guest                 0.418056
# agent                           company                           0.350746
# company                         agent                             0.350746
# children                        adr                               0.324854
# adr                             children                          0.324854
# dtype: float64

# %% [markdown]
# ## 7. Behandlung fehlender Werte

# %%
# wir entfernen die Spalten 'agent' und 'company' aus dem Datensatz
df_both_populated = df[df["company"].notna() & df["agent"].notna()]
print(df_both_populated.shape)
# Out:
# (217, 32)

# %%
from sklearn.impute import SimpleImputer
 
# Verschmelzen der Spalten 'company' und 'agent' zu einer neuen Spalte 'company_agent'
df['company_agent'] = df['company'].fillna(df['agent']).fillna('99999')
df['company'] = df['company'].fillna('99999')
df['agent'] = df['agent'].fillna('99999')
# df.drop(['company', 'agent'], axis=1, inplace=True)
# Imputation für 'children' und 'country'
 
# Imputer für numerische Spalten (children)
imputer_num = SimpleImputer(strategy='median')
df['children'] = imputer_num.fit_transform(df[['children']])
 
# Imputer für kategoriale Spalten (country)
imputer_cat = SimpleImputer(strategy='most_frequent')
# Korrigierte Version - wir konvertieren das 2D-Ergebnis zurück zu 1D mit ravel()
df['country'] = imputer_cat.fit_transform(df[['country']]).ravel()
 
# Überprüfen der Änderungen
print("Erste 5 Zeilen nach der Imputation und Verschmelzung:")
display(df.head())
# Out:
# Erste 5 Zeilen nach der Imputation und Verschmelzung:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  company  \
# 0                        0                     0       2  ...  99999    99999
# 1                        0                     0       2  ...  99999    99999
# 2                        0                     1       1  ...  99999    99999
# 3                        0                     1       1  ...  304.0    99999
# 4                        0                     2       2  ...  240.0    99999
#
#   days_in_waiting_list customer_type   adr required_car_parking_spaces  \
# 0                    0     Transient   0.0                           0
# 1                    0     Transient   0.0                           0
# 2                    0     Transient  75.0                           0
# 3                    0     Transient  75.0                           0
# 4                    0     Transient  98.0                           0
#
#    total_of_special_requests  reservation_status  reservation_status_date  \
# 0                          0           Check-Out               2015-07-01
# 1                          0           Check-Out               2015-07-01
# 2                          0           Check-Out               2015-07-02
# 3                          0           Check-Out               2015-07-02
# 4                          1           Check-Out               2015-07-03
#
#   company_agent
# 0         99999
# 1         99999
# 2         99999
# 3         304.0
# 4         240.0
#
# [5 rows x 33 columns]

# %%
import pandas as pd
import numpy as np

# Debug: Zeige Spalten und Typen
print("Verfügbare Spalten:", df.columns.tolist())
print("Dtypes:\n", df.dtypes)

# Korrekte numeric_columns definieren
numeric_columns = df.select_dtypes(include=[np.number]).columns.tolist()
numeric_columns = [col for col in numeric_columns if col in df.columns]  # Sicherstellen, dass sie existieren

print("Numerische Spalten:", numeric_columns)

if len(numeric_columns) > 0:
    skewness = df[numeric_columns].skew().sort_values(ascending=False)
    kurtosis = df[numeric_columns].kurtosis().sort_values(ascending=False)

    distribution_stats = pd.DataFrame({
        'Schiefe': skewness,
        'Kurtosis': kurtosis
    })
    print(distribution_stats)
else:
    print("Keine numerischen Spalten gefunden.")
# Out:
# Verfügbare Spalten: ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date', 'company_agent']
# Dtypes:
#  hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# deposit_type                       object
# agent                              object
# company                            object
# days_in_waiting_list                int64
# customer_type                      object
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# reservation_status                 object
# reservation_status_date            object
# company_agent                      object
# dtype: object
# Numerische Spalten: ['is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']
#                                   Schiefe     Kurtosis
# adr                             10.530214  1013.189851
# adults                          18.317805  1352.115116
# arrival_date_day_of_month       -0.002000    -1.187168
# arrival_date_week_number        -0.010014    -0.986077
# arrival_date_year               -0.232583    -0.994564
# babies                          24.646545  1633.948235
# booking_changes                  6.000270    79.393605
# children                         4.112670    18.674464
# days_in_waiting_list            11.944353   186.793070
# is_canceled                      0.536678    -1.712005
# is_repeated_guest                5.326315    26.370077
# lead_time                        1.346550     1.696449
# previous_bookings_not_canceled  23.539800   767.245210
# previous_cancellations          24.458049   674.073693
# required_car_parking_spaces      4.163233    29.998056
# stays_in_week_nights             2.862249    24.284555
# stays_in_weekend_nights          1.380046     7.174066
# total_of_special_requests        1.349189     1.492565

# %%
# Analyse der Schiefe und Verteilungsformen numerischer Variablen
if len(numeric_columns) > 0:
    skewness = df[numeric_columns].skew().sort_values(ascending=False)
    kurtosis = df[numeric_columns].kurtosis().sort_values(ascending=False)
    
    distribution_stats = pd.DataFrame({
        'Schiefe': skewness,
        'Kurtosis': kurtosis
    })
    
    print("Verteilungsstatistiken (sortiert nach Schiefe):")
    display(distribution_stats)
    
    # Variablen mit starker Schiefe identifizieren
    high_skew = skewness[abs(skewness) > 1]
    if len(high_skew) > 0:
        print("\nVariablen mit starker Schiefe (|skew| > 1):")
        display(high_skew)
        
        # Log-Transformation für stark schiefe Variablen ze# Analyse der Schiefe und Verteilungsformen numerischer Variablen
if len(numeric_columns) > 0:
    skewness = df[numeric_columns].skew().sort_values(ascending=False)
    kurtosis = df[numeric_columns].kurtosis().sort_values(ascending=False)
    
    distribution_stats = pd.DataFrame({
        'Schiefe': skewness,
        'Kurtosis': kurtosis
    })
    
    print("Verteilungsstatistiken (sortiert nach Schiefe):")
    display(distribution_stats)
    
    # Variablen mit starker Schiefe identifizieren
    high_skew = skewness[abs(skewness) > 1]
    if len(high_skew) > 0:
        print("\nVariablen mit starker Schiefe (|skew| > 1):")
        display(high_skew)
        
        # Log-Transformation für stark schiefe Variablen ze
# Out:
# Verteilungsstatistiken (sortiert nach Schiefe):
#                                   Schiefe     Kurtosis
# adr                             10.530214  1013.189851
# adults                          18.317805  1352.115116
# arrival_date_day_of_month       -0.002000    -1.187168
# arrival_date_week_number        -0.010014    -0.986077
# arrival_date_year               -0.232583    -0.994564
# babies                          24.646545  1633.948235
# booking_changes                  6.000270    79.393605
# children                         4.112670    18.674464
# days_in_waiting_list            11.944353   186.793070
# is_canceled                      0.536678    -1.712005
# is_repeated_guest                5.326315    26.370077
# lead_time                        1.346550     1.696449
# previous_bookings_not_canceled  23.539800   767.245210
# previous_cancellations          24.458049   674.073693
# required_car_parking_spaces      4.163233    29.998056
# stays_in_week_nights             2.862249    24.284555
# stays_in_weekend_nights          1.380046     7.174066
# total_of_special_requests        1.349189     1.492565
# Variablen mit starker Schiefe (|skew| > 1):
# babies                            24.646545
# previous_cancellations            24.458049
# previous_bookings_not_canceled    23.539800
# adults                            18.317805
# days_in_waiting_list              11.944353
# adr                               10.530214
# booking_changes                    6.000270
# is_repeated_guest                  5.326315
# required_car_parking_spaces        4.163233
# children                           4.112670
# stays_in_week_nights               2.862249
# stays_in_weekend_nights            1.380046
# total_of_special_requests          1.349189
# lead_time                          1.346550
# dtype: float64
# Verteilungsstatistiken (sortiert nach Schiefe):
#                                   Schiefe     Kurtosis
# adr                             10.530214  1013.189851
# adults                          18.317805  1352.115116
# arrival_date_day_of_month       -0.002000    -1.187168
# arrival_date_week_number        -0.010014    -0.986077
# arrival_date_year               -0.232583    -0.994564
# babies                          24.646545  1633.948235
# booking_changes                  6.000270    79.393605
# children                         4.112670    18.674464
# days_in_waiting_list            11.944353   186.793070
# is_canceled                      0.536678    -1.712005
# is_repeated_guest                5.326315    26.370077
# lead_time                        1.346550     1.696449
# previous_bookings_not_canceled  23.539800   767.245210
# previous_cancellations          24.458049   674.073693
# required_car_parking_spaces      4.163233    29.998056
# stays_in_week_nights             2.862249    24.284555
# stays_in_weekend_nights          1.380046     7.174066
# total_of_special_requests        1.349189     1.492565
# Variablen mit starker Schiefe (|skew| > 1):
# babies                            24.646545
# previous_cancellations            24.458049
# previous_bookings_not_canceled    23.539800
# adults                            18.317805
# days_in_waiting_list              11.944353
# adr                               10.530214
# booking_changes                    6.000270
# is_repeated_guest                  5.326315
# required_car_parking_spaces        4.163233
# children                           4.112670
# stays_in_week_nights               2.862249
# stays_in_weekend_nights            1.380046
# total_of_special_requests          1.349189
# lead_time                          1.346550
# dtype: float64

# %% [markdown]
# ## 8. Weitere Analysen und Transformationen

# %%
# Analyse der Schiefe und Verteilungsformen numerischer Variablen
if len(numeric_columns) > 0:
    skewness = df[numeric_columns].skew().sort_values(ascending=False)
    kurtosis = df[numeric_columns].kurtosis().sort_values(ascending=False)
    
    distribution_stats = pd.DataFrame({
        'Schiefe': skewness,
        'Kurtosis': kurtosis
    })
    
    print("Verteilungsstatistiken (sortiert nach Schiefe):")
    display(distribution_stats)
    
    # Variablen mit starker Schiefe identifizieren
    high_skew = skewness[abs(skewness) > 1]
    if len(high_skew) > 0:
        print("\nVariablen mit starker Schiefe (|skew| > 1):")
        display(high_skew)
        
        # Log-Transformation für stark schiefe Variablen ze# Analyse der Schiefe und Verteilungsformen numerischer Variablen
if len(numeric_columns) > 0:
    skewness = df[numeric_columns].skew().sort_values(ascending=False)
    kurtosis = df[numeric_columns].kurtosis().sort_values(ascending=False)
    
    distribution_stats = pd.DataFrame({
        'Schiefe': skewness,
        'Kurtosis': kurtosis
    })
    
    print("Verteilungsstatistiken (sortiert nach Schiefe):")
    display(distribution_stats)
    
    # Variablen mit starker Schiefe identifizieren
    high_skew = skewness[abs(skewness) > 1]
    if len(high_skew) > 0:
        print("\nVariablen mit starker Schiefe (|skew| > 1):")
        display(high_skew)
        
        # Log-Transformation für stark schiefe Variablen ze
# Out:
# Verteilungsstatistiken (sortiert nach Schiefe):
#                                   Schiefe     Kurtosis
# adr                             10.530214  1013.189851
# adults                          18.317805  1352.115116
# arrival_date_day_of_month       -0.002000    -1.187168
# arrival_date_week_number        -0.010014    -0.986077
# arrival_date_year               -0.232583    -0.994564
# babies                          24.646545  1633.948235
# booking_changes                  6.000270    79.393605
# children                         4.112670    18.674464
# days_in_waiting_list            11.944353   186.793070
# is_canceled                      0.536678    -1.712005
# is_repeated_guest                5.326315    26.370077
# lead_time                        1.346550     1.696449
# previous_bookings_not_canceled  23.539800   767.245210
# previous_cancellations          24.458049   674.073693
# required_car_parking_spaces      4.163233    29.998056
# stays_in_week_nights             2.862249    24.284555
# stays_in_weekend_nights          1.380046     7.174066
# total_of_special_requests        1.349189     1.492565
# Variablen mit starker Schiefe (|skew| > 1):
# babies                            24.646545
# previous_cancellations            24.458049
# previous_bookings_not_canceled    23.539800
# adults                            18.317805
# days_in_waiting_list              11.944353
# adr                               10.530214
# booking_changes                    6.000270
# is_repeated_guest                  5.326315
# required_car_parking_spaces        4.163233
# children                           4.112670
# stays_in_week_nights               2.862249
# stays_in_weekend_nights            1.380046
# total_of_special_requests          1.349189
# lead_time                          1.346550
# dtype: float64
# Verteilungsstatistiken (sortiert nach Schiefe):
#                                   Schiefe     Kurtosis
# adr                             10.530214  1013.189851
# adults                          18.317805  1352.115116
# arrival_date_day_of_month       -0.002000    -1.187168
# arrival_date_week_number        -0.010014    -0.986077
# arrival_date_year               -0.232583    -0.994564
# babies                          24.646545  1633.948235
# booking_changes                  6.000270    79.393605
# children                         4.112670    18.674464
# days_in_waiting_list            11.944353   186.793070
# is_canceled                      0.536678    -1.712005
# is_repeated_guest                5.326315    26.370077
# lead_time                        1.346550     1.696449
# previous_bookings_not_canceled  23.539800   767.245210
# previous_cancellations          24.458049   674.073693
# required_car_parking_spaces      4.163233    29.998056
# stays_in_week_nights             2.862249    24.284555
# stays_in_weekend_nights          1.380046     7.174066
# total_of_special_requests        1.349189     1.492565
# Variablen mit starker Schiefe (|skew| > 1):
# babies                            24.646545
# previous_cancellations            24.458049
# previous_bookings_not_canceled    23.539800
# adults                            18.317805
# days_in_waiting_list              11.944353
# adr                               10.530214
# booking_changes                    6.000270
# is_repeated_guest                  5.326315
# required_car_parking_spaces        4.163233
# children                           4.112670
# stays_in_week_nights               2.862249
# stays_in_weekend_nights            1.380046
# total_of_special_requests          1.349189
# lead_time                          1.346550
# dtype: float64

# %%
print(df.isnull().sum())
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# company_agent                     0
# dtype: int64

# %%
# Output Ordner auf Desktop speichern 
df.to_csv("/Users/I585032/Desktop/hotel_bookings_processed.csv", index=False)
print("✅ Auf Desktop gespeichert!")
# Out:
# ✅ Auf Desktop gespeichert!

# %%
from pathlib import Path
output_dir = Path.home() / "Projects/data_mining_dsba/data/processed"
print(f"Ordner existiert: {output_dir.exists()}")  # Sollte False sein
# Out:
# Ordner existiert: False

# %%
from pathlib import Path
import os

# 1. ORDNER automatischerweise erstellen
home_dir = Path.home()
output_dir = home_dir / "Projects/data_mining_dsba/data/processed"
output_dir.mkdir(parents=True, exist_ok=True)  # ← MACHT ALLE ORDNER!

# 2. Datei speichern
output_file = output_dir / "hotel_bookings_processed.csv"
df.to_csv(output_file, index=False)

print(f"✅ Data gespeichert: {output_file}")
# Out:
# ✅ Data gespeichert: /Users/I585032/Projects/data_mining_dsba/data/processed/hotel_bookings_processed.csv

# %%
from pathlib import Path

home_dir = Path.home()
output_file = home_dir / "Projects/data_mining_dsba/data/processed/hotel_bookings_processed.csv"
df.to_csv(output_file, index=False)
print(f"Data has been saved to {output_file}")
# Out:
# Data has been saved to /Users/I585032/Projects/data_mining_dsba/data/processed/hotel_bookings_processed.csv
